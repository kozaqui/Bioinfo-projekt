# %%
import sqlite3

# %%
connection = sqlite3.connect('modRNA_test.db')
c = connection.cursor()

# %%
[print(element[0]) for element in c.execute('''SELECT mono_id FROM mod_RNA_list''')]
# Out:
# 0U1
# 10C
# 125
# 126
# 127
# 128
# 12A
# 1DP
# 1MA
# 1MG
# 1PR
# 1RN
# 1SC
# 2AT
# 2AU
# 2BT
# 2GT
# 2MA
# 2MG
# 2MU
# 2NT
# 2OM
# 2OT
# 2SA
# 2SG
# 31H
# 31M
# 3DA
# 3ME
# 3MU
# 3TD
# 4AC
# 4OC
# 4SU
# 4TA
# 574
# 5AA
# 5BU
# 5CF
# 5CG
# 5FA
# 5FU
# 5HM
# 5IC
# 5JO
# 5MC
# 5MU
# 6FC
# 6FU
# 6IA
# 6MC
# 6MT
# 6MZ
# 70U
# 7AT
# 7MG
# 8AN
# A23
# A2L
# A2M
# A39
# A3P
# A44
# A5M
# A5O
# A7E
# A9Z
# ADX
# AET
# AP7
# ATL
# AVC
# BMP
# BMQ
# BOE
# BT5
# C25
# C2L
# C31
# C43
# C5L
# CAR
# CB2
# CBV
# CCC
# CH
# CM0
# CS8
# CSF
# DBM
# DHU
# DJF
# EIT
# ENA
# ENP
# F3N
# F3O
# FA2
# FA5
# FAI
# FHU
# FMU
# G25
# G2L
# G46
# G48
# G4P
# G7M
# GAO
# GDO
# GDP
# GDR
# GH3
# GMU
# GOM
# GRB
# H2U
# I
# IC
# IG
# IPN
# IU
# JLN
# JW5
# KAG
# LC
# LCA
# LCC
# LCG
# LG
# LHU
# LKC
# LMS
# M2G
# M5M
# MA6
# MAD
# MEP
# MGQ
# MGV
# MIA
# MNU
# MTU
# N
# N6G
# NF2
# O2C
# O2G
# OAD
# ODP
# OMC
# OMG
# OMU
# ONE
# P1P
# P2T
# P5P
# PGP
# PMT
# PPU
# PQ1
# PR5
# PSU
# PU
# PUY
# PYO
# PYY
# QUO
# ...

# %%
for element in c.fetchall():
    print(element[0])
# Out:
# 0U1
# 10C
# 125
# 126
# 127
# 128
# 12A
# 1DP
# 1MA
# 1MG
# 1PR
# 1RN
# 1SC
# 2AT
# 2AU
# 2BT
# 2GT
# 2MA
# 2MG
# 2MU
# 2NT
# 2OM
# 2OT
# 2SA
# 2SG
# 31H
# 31M
# 3DA
# 3ME
# 3MU
# 3TD
# 4AC
# 4OC
# 4SU
# 4TA
# 574
# 5AA
# 5BU
# 5CF
# 5CG
# 5FA
# 5FU
# 5HM
# 5IC
# 5JO
# 5MC
# 5MU
# 6FC
# 6FU
# 6IA
# 6MC
# 6MT
# 6MZ
# 70U
# 7AT
# 7MG
# 8AN
# A23
# A2L
# A2M
# A39
# A3P
# A44
# A5M
# A5O
# A7E
# A9Z
# ADX
# AET
# AP7
# ATL
# AVC
# BMP
# BMQ
# BOE
# BT5
# C25
# C2L
# C31
# C43
# C5L
# CAR
# CB2
# CBV
# CCC
# CH
# CM0
# CS8
# CSF
# DBM
# DHU
# DJF
# EIT
# ENA
# ENP
# F3N
# F3O
# FA2
# FA5
# FAI
# FHU
# FMU
# G25
# G2L
# G46
# G48
# G4P
# G7M
# GAO
# GDO
# GDP
# GDR
# GH3
# GMU
# GOM
# GRB
# H2U
# I
# IC
# IG
# IPN
# IU
# JLN
# JW5
# KAG
# LC
# LCA
# LCC
# LCG
# LG
# LHU
# LKC
# LMS
# M2G
# M5M
# MA6
# MAD
# MEP
# MGQ
# MGV
# MIA
# MNU
# MTU
# N
# N6G
# NF2
# O2C
# O2G
# OAD
# ODP
# OMC
# OMG
# OMU
# ONE
# P1P
# P2T
# P5P
# PGP
# PMT
# PPU
# PQ1
# PR5
# PSU
# PU
# PUY
# PYO
# PYY
# QUO
# ...

# %%
print(c.fetchall())
# Out:
# [('0U1',), ('10C',), ('125',), ('126',), ('127',), ('128',), ('12A',), ('1DP',), ('1MA',), ('1MG',), ('1PR',), ('1RN',), ('1SC',), ('2AT',), ('2AU',), ('2BT',), ('2GT',), ('2MA',), ('2MG',), ('2MU',), ('2NT',), ('2OM',), ('2OT',), ('2SA',), ('2SG',), ('31H',), ('31M',), ('3DA',), ('3ME',), ('3MU',), ('3TD',), ('4AC',), ('4OC',), ('4SU',), ('4TA',), ('574',), ('5AA',), ('5BU',), ('5CF',), ('5CG',), ('5FA',), ('5FU',), ('5HM',), ('5IC',), ('5JO',), ('5MC',), ('5MU',), ('6FC',), ('6FU',), ('6IA',), ('6MC',), ('6MT',), ('6MZ',), ('70U',), ('7AT',), ('7MG',), ('8AN',), ('A23',), ('A2L',), ('A2M',), ('A39',), ('A3P',), ('A44',), ('A5M',), ('A5O',), ('A7E',), ('A9Z',), ('ADX',), ('AET',), ('AP7',), ('ATL',), ('AVC',), ('BMP',), ('BMQ',), ('BOE',), ('BT5',), ('C25',), ('C2L',), ('C31',), ('C43',), ('C5L',), ('CAR',), ('CB2',), ('CBV',), ('CCC',), ('CH',), ('CM0',), ('CS8',), ('CSF',), ('DBM',), ('DHU',), ('DJF',), ('EIT',), ('ENA',), ('ENP',), ('F3N',), ('F3O',), ('FA2',), ('FA5',), ('FAI',)
# ...

# %%
RNA_mod_list = [element[0] for element in c.execute('''SELECT mono_id FROM mod_RNA_list''')]

# %%
RNA_mod_list
# Out:
# ['0U1',
#  '10C',
#  '125',
#  '126',
#  '127',
#  '128',
#  '12A',
#  '1DP',
#  '1MA',
#  '1MG',
#  '1PR',
#  '1RN',
#  '1SC',
#  '2AT',
#  '2AU',
#  '2BT',
#  '2GT',
#  '2MA',
#  '2MG',
#  '2MU',
#  '2NT',
#  '2OM',
#  '2OT',
#  '2SA',
#  '2SG',
#  '31H',
#  '31M',
#  '3DA',
#  '3ME',
#  '3MU',
#  '3TD',
#  '4AC',
#  '4OC',
#  '4SU',
#  '4TA',
#  '574',
#  '5AA',
#  '5BU',
#  '5CF',
#  '5CG',
#  '5FA',
#  '5FU',
#  '5HM',
#  '5IC',
#  '5JO',
#  '5MC',
#  '5MU',
#  '6FC',
#  '6FU',
#  '6IA',
#  '6MC',
#  '6MT',
#  '6MZ',
#  '70U',
#  '7AT',
#  '7MG',
#  '8AN',
#  'A23',
#  'A2L',
#  'A2M',
#  'A39',
#  'A3P',
#  'A44',
#  'A5M',
#  'A5O',
#  'A7E',
#  'A9Z',
#  'ADX',
#  'AET',
#  'AP7',
#  'ATL',
#  'AVC',
#  'BMP',
#  'BMQ',
#  'BOE',
#  'BT5',
#  'C25',
#  'C2L',
#  'C31',
#  'C43',
#  'C5L',
#  'CAR',
#  'CB2',
#  'CBV',
#  'CCC',
#  'CH',
#  'CM0',
#  'CS8',
#  'CSF',
#  'DBM',
#  'DHU',
#  'DJF',
#  'EIT',
#  'ENA',
#  'ENP',
#  'F3N',
#  'F3O',
#  'FA2',
#  'FA5',
#  'FAI',
# ...
